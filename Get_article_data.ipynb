# %%
import pandas as pd
from get_data import get_article_data
df = get_article_data()
# Out:
# [nltk_data] Downloading package stopwords to /home/gitpod/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/gitpod/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/gitpod/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/gitpod/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/gitpod/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
df
# Out:
#                                                  Link  \
# 0   https://dev.to/jsdevspace/mastering-timers-in-...
# 1   https://dev.to/nikhilgoesfullstack/hello-devs-...
# 2   https://dev.to/h1bertobarbosa/como-testes-muda...
# 3   https://dev.to/gilles_hamelink_ea9ff7d93/unloc...
# 4   https://dev.to/adetola_jesulayomi_e3bd55/pytho...
# 5   https://dev.to/dpc/daily-javascript-challenge-...
# 6   https://dev.to/imevanc/micro-frontend-turborep...
# 7   https://dev.to/timo_reusch/insights-into-kerbe...
# 8   https://dev.to/peter_samuel_052b9056e236/how-t...
# 9   https://dev.to/foxgem/code-explanation-nanogpt...
# 10  https://dev.to/lgerthal/testing-google-cloud-f...
# 11  https://dev.to/theaniketrajdev/introducing-cei...
# 12  https://dev.to/besworks/convert-video-to-anima...
# 13      https://dev.to/inaciobrwi/protocolo-http-1c63
# 14  https://dev.to/timo_reusch/an-introduction-to-...
# 15  https://dev.to/inaciobrwi/terminal-a-famosa-te...
# 16  https://dev.to/matthijsschuurman/how-to-code-l...
# 17  https://dev.to/victor_kiprotich_9328c6fc/how-t...
# 18  https://dev.to/skilleddevs/programming-doesnt-...
# 19  https://dev.to/timo_reusch/what-exactly-is-act...
# 20  https://dev.to/macmartins/what-is-devrel-and-w...
# 21  https://dev.to/idevgames/how-to-add-scroll-ani...
# 22  https://dev.to/timo_reusch/active-directory-th...
# 23  https://dev.to/ezodude/semantic-caching-for-ll...
# 24    https://dev.to/dwane/day-1122-curtain-call-35pg
#
#                                                 Title         Time Uploaded  \
# 0   Mastering Timers in React: A Comprehensive Dev...  2025-03-18T00:00:58Z
# 1                                      Hello, devs! 👋  2025-03-18T00:34:20Z
# 2        Como testes mudaram minha forma de trabalhar  2025-03-18T00:30:10Z
# 3   "Unlocking Quantum Error Correction: The Power...  2025-03-18T00:12:48Z
# 4   Python Tips for Beginners: A Guide to Writing ...  2025-03-18T00:06:37Z
# 5   Daily JavaScript Challenge #JS-128: Find First...  2025-03-18T00:00:49Z
# 6   🚀 Micro Frontend Turborepo Starter: A Scalable...  2025-03-17T23:55:32Z
# 7                              Insights into Kerberos  2025-03-17T23:45:23Z
# 8            How to Create a Virtual Machine on Azure  2025-03-17T23:43:56Z
# 9                           Code Explanation: nanoGPT  2025-03-17T23:41:08Z
# 10             Testing Google Cloud Functions Locally  2025-03-17T23:31:43Z
# 11  🚀 Introducing CEIE 1.0 & 2.0: The Next Evoluti...  2025-03-17T23:23:38Z
# 12  Convert Video to Animated WebP Using FFmpeg Wi...  2025-03-17T23:17:54Z
# 13                                     Protocolo HTTP  2025-03-17T23:14:23Z
# 14                            An introduction to LDAP  2025-03-17T23:05:01Z
# 15                      Terminal, a famosa tela preta  2025-03-17T23:04:40Z
# 16                           How to code like a boss?  2025-03-17T22:56:20Z
# 17  How to change password and username in Kali linux  2025-03-17T22:51:00Z
# 18  Programming Doesn’t Happen at the Keyboard — B...  2025-03-17T22:48:04Z
# 19                  What exactly is Active Directory?  2025-03-17T22:46:47Z
# 20         What is DevRel and why are they important?  2025-03-17T22:34:14Z
# 21  How to Add Scroll Animations in Webflow, WordP...  2025-03-17T22:31:35Z
# 22    Active Directory: The Backbone of Enterprise IT  2025-03-17T22:24:13Z
# 23  Semantic Caching for LLM Execution Plans: How ...  2025-03-17T22:23:34Z
# 24                            Day 1122 : Curtain Call  2025-03-17T22:20:48Z
#
#                        Author  \
# 0                 JSDev Space
# 1       nikhil keolan gounden
# 2   Humberto Oliveira Barbosa
# 3             Gilles Hamelink
# 4          Adetola Jesulayomi
# 5                         DPC
# 6          Evan Charalampidis
# 7                 Timo Reusch
# 8                PETER Samuel
# 9                      foxgem
# 10        Luiz Gustavo Erthal
# 11                 Aniket Raj
# 12                   Besworks
# 13                  InacioBrw
# 14                Timo Reusch
# 15                  InacioBrw
# 16                   Matthijs
# 17           Victor Kiprotich
# 18               Skilled Devs
# 19                Timo Reusch
# 20               Obinna Aguwa
# 21                 iDev-Games
# 22                Timo Reusch
# 23                  Ezo Saleh
# 24            HIPHOP and CODE
#
#                                                  Tags Reading Time  \
# 0                   #webdev#react#javascript#frontend   2 min read
# 1                            #coding#southafrican#web   1 min read
# 2                         #programming#test#beginners   1 min read
# 3                                                       7 min read
# 4             #programming#python#cleancode#beginners   3 min read
# 5         #javascript#devchallenge#programming#webdev   1 min read
# 6                     #react#typescript#vercel#webdev   2 min read
# 7                                                       3 min read
# 8   #virtualmachine#azurelearning#fromzerotohero#d...   2 min read
# 9                             #ai#llm#chatgpt#aiagent   5 min read
# 10                                                      3 min read
# 11               #devops#github#opensource#automation   2 min read
# 12                            #bash#linux#ffmpeg#webp   3 min read
# 13                                                      3 min read
# 14                                                      2 min read
# 15                                                      1 min read
# 16                               #kiss#coding#testing   9 min read
# 17                                                #li   1 min read
# 18         #programming#beginners#productivity#career   2 min read
# 19                                         #microsoft   3 min read
# 20                                                      2 min read
# 21           #webdev#programming#javascript#beginners   3 min read
# 22                                         #microsoft   1 min read
# 23                          #ai#opensource#go#tooling   9 min read
# 24                    #hiphop#code#coding#lifelongdev   2 min read
#
#                                       Article Content  Word Count Sentiment  \
# 0   Timers in React can be tricky if you don’t con...         111  Positive
# 1   I’m a passionate software developer diving dee...          57  Positive
# 2   Antes, eu confiava no feeling. Escrevia código...         223  Negative
# 3    In the rapidly evolving landscape of quantum ...        1276  Positive
# 4   Learning Python has been one of the most inten...         558  Positive
# 5   Hey fellow developers! 👋 Welcome to today's Ja...          77  Negative
# 6   Micro frontends have emerged as a game-changer...         374  Positive
# 7   A crucial protocol in the context of AD is Ker...         346  Positive
# 8   What is a virtual machine\nIn the context of M...         159  Positive
# 9   Disclaimer: this is a report generated with my...         178  Positive
# 10  Google Cloud Functions is a serverless compute...         213  Positive
# 11  Hi Dev.to! 👋 I’m excited to share my latest pr...         211  Positive
# 12  Recently I had a need to clip a compilation vi...         299  Positive
# 13   Da sigla Hypertext transfer protocol \nProtoc...         429  Negative
# 14  Lightweight Directory Access Protocol (LDAP) i...         302  Positive
# 15  E para responder essa pergunta, precisamos vol...         181   Neutral
# 16  Simple, allow yourself to code like a boss! \n...         980  Positive
# 17  1.The first thing you will need to do is  rebo...          28   Neutral
# 18  Early in my career, a senior manager told me s...         313  Positive
# 19  AD is a collective term for five server roles ...         160  Positive
# 20  Not many people are familiar with the term "De...         347  Positive
# 21  Scroll animations can make your website feel d...         262  Positive
# 22  In the world of enterprise IT, Active Director...          67  Positive
# 23  In this technical deep dive, we'll explore how...         813  Positive
# 24  liner notes:  Sunday : Did my study sessions o...         160  Positive
#
#     Compound Score
# 0           0.7906
# 1           0.9519
# 2          -0.4404
# 3           0.9997
# 4           0.9975
# 5          -0.3956
# 6           0.9882
# 7           0.9816
# 8           0.8932
# 9           0.8860
# 10          0.9140
# 11          0.9948
# 12          0.9930
# 13         -0.8176
# 14          0.9866
# 15          0.0000
# 16          0.9973
# 17          0.0000
# 18          0.5994
# 19          0.9758
# 20          0.9981
# 21          0.9846
# 22          0.6640
# 23          0.9979
# 24          0.9884

# %%
#Iterate through each column name.

#Replace any spaces in the column name with underscores (_).
#Example: "Time Uploaded" becomes "time_uploaded".

# Initialize an empty list to store the results
article_list = []


# Loop through each row in the DataFrame using iterrows()
for index, row in df.iterrows():
    try:
        Link = row['Link']  # Access the 'Link' column by name
        Title = row['Title']  # Access the 'Title' column by name
        Time_Uploaded = row['Time Uploaded']  # Access the 'Time Uploaded' column by name
        Author = row['Author']  # Access the 'Author' column by name
        Tags = row['Tags']  # Access the 'Tags' column by name (check if there’s an extra space)
        Reading_Time = row['Reading Time']  # Access the 'Reading Time' column by name
        Article_Content = row['Article Content']  # Access the 'Article Content' column by name
        Word_Count = row['Word Count']  # Access the 'Word Count' column by name
        Sentiment = row['Sentiment']  # Access the 'Sentiment' column by name
        Compound_Score=row['Compound Score']
    except KeyError as e:
        print(f"Column not found: {e}")
        continue  # Skip rows where any column is missing

    # Append the tuple (Link, Title, Time_Uploaded, Author, Tags, Reading_Time, Article_Content, Word_Count, Sentiment)
    article_list.append((Link, Title, Time_Uploaded, Author, Tags, Reading_Time, Article_Content, Word_Count, Sentiment,Compound_Score))

# Now article_list contains tuples of (Link, Title, Time_Uploaded, Author, Tags, Reading_Time, Article_Content, Word_Count, Sentiment)
df_list
# Out:
#                                                  link  \
# 0   https://dev.to/matthijsschuurman/how-to-code-l...
# 1   https://dev.to/besworks/convert-video-to-anima...
# 2   https://dev.to/timo_reusch/an-introduction-to-...
# 3   https://dev.to/inaciobrwi/terminal-a-famosa-te...
# 4   https://dev.to/victor_kiprotich_9328c6fc/how-t...
# 5   https://dev.to/skilleddevs/programming-doesnt-...
# 6   https://dev.to/timo_reusch/what-exactly-is-act...
# 7   https://dev.to/macmartins/what-is-devrel-and-w...
# 8   https://dev.to/idevgames/how-to-add-scroll-ani...
# 9   https://dev.to/timo_reusch/active-directory-th...
# 10  https://dev.to/ezodude/semantic-caching-for-ll...
# 11    https://dev.to/dwane/day-1122-curtain-call-35pg
# 12  https://dev.to/marlusx/check-out-the-new-stack...
# 13  https://dev.to/leoikeh99/build-a-sleek-sortabl...
# 14  https://dev.to/artur_alekseev/integration-test...
# 15  https://dev.to/pranavjana/kendoreact-component...
# 16  https://dev.to/jondoe-666/cafeto-my-first-plug...
# 17  https://dev.to/aneeqakhan/react-suspense-and-c...
# 18  https://dev.to/mustache/from-json-string-to-ja...
# 19  https://dev.to/js_cipher/meet-domsculpt-a-java...
# 20  https://dev.to/mongodb/better-aggregation-pipe...
# 21  https://dev.to/teki_solves_fb72717580279/maste...
# 22  https://dev.to/maddiepst/transportation-on-vac...
# 23  https://dev.to/peytonstrahan/what-is-material-...
# 24  https://dev.to/sirlawdin/using-iac-terraform-t...
#
#                                                 title time_uploaded  \
# 0                            How to code like a boss?    2025-03-17
# 1   Convert Video to Animated WebP Using FFmpeg Wi...    2025-03-17
# 2                             An introduction to LDAP    2025-03-17
# 3                       Terminal, a famosa tela preta    2025-03-17
# 4   How to change password and username in Kali linux    2025-03-17
# 5   Programming Doesn’t Happen at the Keyboard — B...    2025-03-17
# 6                   What exactly is Active Directory?    2025-03-17
# 7          What is DevRel and why are they important?    2025-03-17
# 8   How to Add Scroll Animations in Webflow, WordP...    2025-03-17
# 9     Active Directory: The Backbone of Enterprise IT    2025-03-17
# 10  Semantic Caching for LLM Execution Plans: How ...    2025-03-17
# 11                            Day 1122 : Curtain Call    2025-03-17
# 12                   Check out the new Stack Builder!    2025-03-17
# 13  Build a Sleek & Sortable Drag-and-Drop Kanban ...    2025-03-17
# 14    Integration Tests Using Cypress Next and Prisma    2025-03-17
# 15                      KendoReact Component Explorer    2025-03-17
# 16                    Cafeto: My First Plugin on PyPI    2025-03-17
# 17  React Suspense and Concurrent Rendering: The F...    2025-03-17
# 18  From JSON String to JavaScript Object: The Ult...    2025-03-17
# 19  Meet DOMSculpt, a JavaScript tool for generati...    2025-03-17
# 20  Better Aggregation Pipeline Support in the Mon...    2025-03-17
# 21  Master Advanced CSS Selectors: Techniques You ...    2025-03-17
# 22                         Transportation on vacation    2025-03-17
# 23            What is Material UI? (React/JavaScript)    2025-03-17
# 24  Using IaC (Terraform) to Deploy a FastAPI Micr...    2025-03-17
#
#                      author                                            tags  \
# 0                  Matthijs                            #kiss#coding#testing
# 1                  Besworks                         #bash#linux#ffmpeg#webp
# 2               Timo Reusch
# 3                 InacioBrw
# 4          Victor Kiprotich                                             #li
# 5              Skilled Devs      #programming#beginners#productivity#career
# 6               Timo Reusch                                      #microsoft
# 7              Obinna Aguwa
# 8                iDev-Games        #webdev#programming#javascript#beginners
# 9               Timo Reusch                                      #microsoft
# 10                Ezo Saleh                       #ai#opensource#go#tooling
# 11          HIPHOP and CODE                 #hiphop#code#coding#lifelongdev
# 12           Marcus Ahlfors                    #webdev#devops#cloud#startup
# 13             Leonard Ikeh            #react#draganddrop#webdev#javascript
# 14         Artur Aliakseyeu               #javascript#cypress#tutorial#node
# 15              Pranav jana  #devchallenge#kendoreactchallenge#react#webdev
# 16         Jonathan Espinal                              #python#api#webdev
# 17              Aneeqa Khan                     #react#ui#webdev#javascript
# 18             Mustache Dev              #webdev#programming#javascript#api
# 19      Temiloluwa Akintade     #webdev#javascript#developertools#beginners
# 20           MongoDB Guests                     #php#mongodb#queries#webdev
# 21              Teki Solves                #webdev#programming#css#frontend
# 22          Madalina Pastiu             #challenge#javascript#codewars#8kyu
# 23           Peyton Strahan
# 24  Salaudeen O. Abdulrasaq                  #devops#aws#datadog#monitoring
#
#     reading_time                                    article_content  \
# 0              9  Simple, allow yourself to code like a boss! Ho...
# 1              3  Recently I had a need to clip a compilation vi...
# 2              2  Lightweight Directory Access Protocol (LDAP) i...
# 3              1  E para responder essa pergunta, precisamos vol...
# 4              1  1.The first thing you will need to do is  rebo...
# 5              2  Early in my career, a senior manager told me s...
# 6              3  AD is a collective term for five server roles ...
# 7              2  Not many people are familiar with the term "De...
# 8              3  Scroll animations can make your website feel d...
# 9              1  In the world of enterprise IT, Active Director...
# 10             9  In this technical deep dive, we'll explore how...
# 11             2  liner notes:  Sunday : Did my study sessions o...
# 12             1
# 13             6  Creating a kanaban drag n drop component layou...
# 14             7  In this article, I’ll walk you through setting...
# 15             2  This is a submission for the . As you probably...
# 16             1  After much learning and hard work, I’m excited...
# 17             3  React has always been at the forefront of buil...
# 18             5   Hey there! Today we're going to learn how to ...
# 19             5  I created DOMSculpt for the sole purpose of si...
# 20            13  This tutorial was written by .  The aggregatio...
# 21             1  CSS selectors are more powerful than most deve...
# 22             1  Instructions:After a hard quarter in the offic...
# 23             7  IntroMaterial UI (MUI) is a 2014 JavaScript Li...
# 24             4  Modern cloud applications need scalability, ob...
#
#     word_count sentiment  compound_score
# 0          980  Positive          0.9973
# 1          299  Positive          0.9930
# 2          302  Positive          0.9866
# 3          181   Neutral          0.0000
# 4           28   Neutral          0.0000
# 5          313  Positive          0.5994
# 6          160  Positive          0.9758
# 7          347  Positive          0.9981
# 8          262  Positive          0.9846
# 9           67  Positive          0.6640
# 10         813  Positive          0.9979
# 11         160  Positive          0.9884
# 12           0   Neutral          0.0000
# 13         429  Positive          0.9904
# 14         638  Positive          0.9964
# 15         350  Positive          0.9976
# 16          59  Positive          0.9167
# 17         329  Positive          0.9907
# 18         334  Positive          0.9960
# 19         533  Positive          0.9931
# 20        1607  Positive          0.9994
# 21         115  Positive          0.9830
# 22          81   Neutral          0.0258
# 23         886  Positive          0.9960
# 24         297  Positive          0.9719

# %%
#Convert the column name to lowercase.
df_list.columns = df_list.columns.str.lower()
df_list
# Out:
#                                                  link  \
# 0   https://dev.to/matthijsschuurman/how-to-code-l...
# 1   https://dev.to/besworks/convert-video-to-anima...
# 2   https://dev.to/timo_reusch/an-introduction-to-...
# 3   https://dev.to/inaciobrwi/terminal-a-famosa-te...
# 4   https://dev.to/victor_kiprotich_9328c6fc/how-t...
# 5   https://dev.to/skilleddevs/programming-doesnt-...
# 6   https://dev.to/timo_reusch/what-exactly-is-act...
# 7   https://dev.to/macmartins/what-is-devrel-and-w...
# 8   https://dev.to/idevgames/how-to-add-scroll-ani...
# 9   https://dev.to/timo_reusch/active-directory-th...
# 10  https://dev.to/ezodude/semantic-caching-for-ll...
# 11    https://dev.to/dwane/day-1122-curtain-call-35pg
# 12  https://dev.to/marlusx/check-out-the-new-stack...
# 13  https://dev.to/leoikeh99/build-a-sleek-sortabl...
# 14  https://dev.to/artur_alekseev/integration-test...
# 15  https://dev.to/pranavjana/kendoreact-component...
# 16  https://dev.to/jondoe-666/cafeto-my-first-plug...
# 17  https://dev.to/aneeqakhan/react-suspense-and-c...
# 18  https://dev.to/mustache/from-json-string-to-ja...
# 19  https://dev.to/js_cipher/meet-domsculpt-a-java...
# 20  https://dev.to/mongodb/better-aggregation-pipe...
# 21  https://dev.to/teki_solves_fb72717580279/maste...
# 22  https://dev.to/maddiepst/transportation-on-vac...
# 23  https://dev.to/peytonstrahan/what-is-material-...
# 24  https://dev.to/sirlawdin/using-iac-terraform-t...
#
#                                                 title time_uploaded  \
# 0                            How to code like a boss?    2025-03-17
# 1   Convert Video to Animated WebP Using FFmpeg Wi...    2025-03-17
# 2                             An introduction to LDAP    2025-03-17
# 3                       Terminal, a famosa tela preta    2025-03-17
# 4   How to change password and username in Kali linux    2025-03-17
# 5   Programming Doesn’t Happen at the Keyboard — B...    2025-03-17
# 6                   What exactly is Active Directory?    2025-03-17
# 7          What is DevRel and why are they important?    2025-03-17
# 8   How to Add Scroll Animations in Webflow, WordP...    2025-03-17
# 9     Active Directory: The Backbone of Enterprise IT    2025-03-17
# 10  Semantic Caching for LLM Execution Plans: How ...    2025-03-17
# 11                            Day 1122 : Curtain Call    2025-03-17
# 12                   Check out the new Stack Builder!    2025-03-17
# 13  Build a Sleek & Sortable Drag-and-Drop Kanban ...    2025-03-17
# 14    Integration Tests Using Cypress Next and Prisma    2025-03-17
# 15                      KendoReact Component Explorer    2025-03-17
# 16                    Cafeto: My First Plugin on PyPI    2025-03-17
# 17  React Suspense and Concurrent Rendering: The F...    2025-03-17
# 18  From JSON String to JavaScript Object: The Ult...    2025-03-17
# 19  Meet DOMSculpt, a JavaScript tool for generati...    2025-03-17
# 20  Better Aggregation Pipeline Support in the Mon...    2025-03-17
# 21  Master Advanced CSS Selectors: Techniques You ...    2025-03-17
# 22                         Transportation on vacation    2025-03-17
# 23            What is Material UI? (React/JavaScript)    2025-03-17
# 24  Using IaC (Terraform) to Deploy a FastAPI Micr...    2025-03-17
#
#                      author                                            tags  \
# 0                  Matthijs                            #kiss#coding#testing
# 1                  Besworks                         #bash#linux#ffmpeg#webp
# 2               Timo Reusch
# 3                 InacioBrw
# 4          Victor Kiprotich                                             #li
# 5              Skilled Devs      #programming#beginners#productivity#career
# 6               Timo Reusch                                      #microsoft
# 7              Obinna Aguwa
# 8                iDev-Games        #webdev#programming#javascript#beginners
# 9               Timo Reusch                                      #microsoft
# 10                Ezo Saleh                       #ai#opensource#go#tooling
# 11          HIPHOP and CODE                 #hiphop#code#coding#lifelongdev
# 12           Marcus Ahlfors                    #webdev#devops#cloud#startup
# 13             Leonard Ikeh            #react#draganddrop#webdev#javascript
# 14         Artur Aliakseyeu               #javascript#cypress#tutorial#node
# 15              Pranav jana  #devchallenge#kendoreactchallenge#react#webdev
# 16         Jonathan Espinal                              #python#api#webdev
# 17              Aneeqa Khan                     #react#ui#webdev#javascript
# 18             Mustache Dev              #webdev#programming#javascript#api
# 19      Temiloluwa Akintade     #webdev#javascript#developertools#beginners
# 20           MongoDB Guests                     #php#mongodb#queries#webdev
# 21              Teki Solves                #webdev#programming#css#frontend
# 22          Madalina Pastiu             #challenge#javascript#codewars#8kyu
# 23           Peyton Strahan
# 24  Salaudeen O. Abdulrasaq                  #devops#aws#datadog#monitoring
#
#     reading_time                                    article_content  \
# 0              9  Simple, allow yourself to code like a boss! Ho...
# 1              3  Recently I had a need to clip a compilation vi...
# 2              2  Lightweight Directory Access Protocol (LDAP) i...
# 3              1  E para responder essa pergunta, precisamos vol...
# 4              1  1.The first thing you will need to do is  rebo...
# 5              2  Early in my career, a senior manager told me s...
# 6              3  AD is a collective term for five server roles ...
# 7              2  Not many people are familiar with the term "De...
# 8              3  Scroll animations can make your website feel d...
# 9              1  In the world of enterprise IT, Active Director...
# 10             9  In this technical deep dive, we'll explore how...
# 11             2  liner notes:  Sunday : Did my study sessions o...
# 12             1
# 13             6  Creating a kanaban drag n drop component layou...
# 14             7  In this article, I’ll walk you through setting...
# 15             2  This is a submission for the . As you probably...
# 16             1  After much learning and hard work, I’m excited...
# 17             3  React has always been at the forefront of buil...
# 18             5   Hey there! Today we're going to learn how to ...
# 19             5  I created DOMSculpt for the sole purpose of si...
# 20            13  This tutorial was written by .  The aggregatio...
# 21             1  CSS selectors are more powerful than most deve...
# 22             1  Instructions:After a hard quarter in the offic...
# 23             7  IntroMaterial UI (MUI) is a 2014 JavaScript Li...
# 24             4  Modern cloud applications need scalability, ob...
#
#     word_count sentiment  compound_score
# 0          980  Positive          0.9973
# 1          299  Positive          0.9930
# 2          302  Positive          0.9866
# 3          181   Neutral          0.0000
# 4           28   Neutral          0.0000
# 5          313  Positive          0.5994
# 6          160  Positive          0.9758
# 7          347  Positive          0.9981
# 8          262  Positive          0.9846
# 9           67  Positive          0.6640
# 10         813  Positive          0.9979
# 11         160  Positive          0.9884
# 12           0   Neutral          0.0000
# 13         429  Positive          0.9904
# 14         638  Positive          0.9964
# 15         350  Positive          0.9976
# 16          59  Positive          0.9167
# 17         329  Positive          0.9907
# 18         334  Positive          0.9960
# 19         533  Positive          0.9931
# 20        1607  Positive          0.9994
# 21         115  Positive          0.9830
# 22          81   Neutral          0.0258
# 23         886  Positive          0.9960
# 24         297  Positive          0.9719

# %%
#Access the "reading_time" column.
#For each value in the column, remove the string " min read" from the end.
#Ensure that the remaining value in the column is converted to the appropriate datatype, probably an integer.

#Access the "reading_time" column.
df_list["reading_time"] = df_list ["reading_time"].astype(str)

#For each value in the column, remove the string " min read" from the end.
df_list["reading_time"]=  df_list ["reading_time"].str.replace(' min read','', regex=False)

#Ensure that the remaining value in the column is converted to the appropriate datatype, probably an integer.
df_list["reading_time"]= df_list ["reading_time"].astype(int)

df_list
# Out:
#                                                  link  \
# 0   https://dev.to/matthijsschuurman/how-to-code-l...
# 1   https://dev.to/besworks/convert-video-to-anima...
# 2   https://dev.to/timo_reusch/an-introduction-to-...
# 3   https://dev.to/inaciobrwi/terminal-a-famosa-te...
# 4   https://dev.to/victor_kiprotich_9328c6fc/how-t...
# 5   https://dev.to/skilleddevs/programming-doesnt-...
# 6   https://dev.to/timo_reusch/what-exactly-is-act...
# 7   https://dev.to/macmartins/what-is-devrel-and-w...
# 8   https://dev.to/idevgames/how-to-add-scroll-ani...
# 9   https://dev.to/timo_reusch/active-directory-th...
# 10  https://dev.to/ezodude/semantic-caching-for-ll...
# 11    https://dev.to/dwane/day-1122-curtain-call-35pg
# 12  https://dev.to/marlusx/check-out-the-new-stack...
# 13  https://dev.to/leoikeh99/build-a-sleek-sortabl...
# 14  https://dev.to/artur_alekseev/integration-test...
# 15  https://dev.to/pranavjana/kendoreact-component...
# 16  https://dev.to/jondoe-666/cafeto-my-first-plug...
# 17  https://dev.to/aneeqakhan/react-suspense-and-c...
# 18  https://dev.to/mustache/from-json-string-to-ja...
# 19  https://dev.to/js_cipher/meet-domsculpt-a-java...
# 20  https://dev.to/mongodb/better-aggregation-pipe...
# 21  https://dev.to/teki_solves_fb72717580279/maste...
# 22  https://dev.to/maddiepst/transportation-on-vac...
# 23  https://dev.to/peytonstrahan/what-is-material-...
# 24  https://dev.to/sirlawdin/using-iac-terraform-t...
#
#                                                 title time_uploaded  \
# 0                            How to code like a boss?    2025-03-17
# 1   Convert Video to Animated WebP Using FFmpeg Wi...    2025-03-17
# 2                             An introduction to LDAP    2025-03-17
# 3                       Terminal, a famosa tela preta    2025-03-17
# 4   How to change password and username in Kali linux    2025-03-17
# 5   Programming Doesn’t Happen at the Keyboard — B...    2025-03-17
# 6                   What exactly is Active Directory?    2025-03-17
# 7          What is DevRel and why are they important?    2025-03-17
# 8   How to Add Scroll Animations in Webflow, WordP...    2025-03-17
# 9     Active Directory: The Backbone of Enterprise IT    2025-03-17
# 10  Semantic Caching for LLM Execution Plans: How ...    2025-03-17
# 11                            Day 1122 : Curtain Call    2025-03-17
# 12                   Check out the new Stack Builder!    2025-03-17
# 13  Build a Sleek & Sortable Drag-and-Drop Kanban ...    2025-03-17
# 14    Integration Tests Using Cypress Next and Prisma    2025-03-17
# 15                      KendoReact Component Explorer    2025-03-17
# 16                    Cafeto: My First Plugin on PyPI    2025-03-17
# 17  React Suspense and Concurrent Rendering: The F...    2025-03-17
# 18  From JSON String to JavaScript Object: The Ult...    2025-03-17
# 19  Meet DOMSculpt, a JavaScript tool for generati...    2025-03-17
# 20  Better Aggregation Pipeline Support in the Mon...    2025-03-17
# 21  Master Advanced CSS Selectors: Techniques You ...    2025-03-17
# 22                         Transportation on vacation    2025-03-17
# 23            What is Material UI? (React/JavaScript)    2025-03-17
# 24  Using IaC (Terraform) to Deploy a FastAPI Micr...    2025-03-17
#
#                      author                                            tags  \
# 0                  Matthijs                            #kiss#coding#testing
# 1                  Besworks                         #bash#linux#ffmpeg#webp
# 2               Timo Reusch
# 3                 InacioBrw
# 4          Victor Kiprotich                                             #li
# 5              Skilled Devs      #programming#beginners#productivity#career
# 6               Timo Reusch                                      #microsoft
# 7              Obinna Aguwa
# 8                iDev-Games        #webdev#programming#javascript#beginners
# 9               Timo Reusch                                      #microsoft
# 10                Ezo Saleh                       #ai#opensource#go#tooling
# 11          HIPHOP and CODE                 #hiphop#code#coding#lifelongdev
# 12           Marcus Ahlfors                    #webdev#devops#cloud#startup
# 13             Leonard Ikeh            #react#draganddrop#webdev#javascript
# 14         Artur Aliakseyeu               #javascript#cypress#tutorial#node
# 15              Pranav jana  #devchallenge#kendoreactchallenge#react#webdev
# 16         Jonathan Espinal                              #python#api#webdev
# 17              Aneeqa Khan                     #react#ui#webdev#javascript
# 18             Mustache Dev              #webdev#programming#javascript#api
# 19      Temiloluwa Akintade     #webdev#javascript#developertools#beginners
# 20           MongoDB Guests                     #php#mongodb#queries#webdev
# 21              Teki Solves                #webdev#programming#css#frontend
# 22          Madalina Pastiu             #challenge#javascript#codewars#8kyu
# 23           Peyton Strahan
# 24  Salaudeen O. Abdulrasaq                  #devops#aws#datadog#monitoring
#
#     reading_time                                    article_content  \
# 0              9  Simple, allow yourself to code like a boss! Ho...
# 1              3  Recently I had a need to clip a compilation vi...
# 2              2  Lightweight Directory Access Protocol (LDAP) i...
# 3              1  E para responder essa pergunta, precisamos vol...
# 4              1  1.The first thing you will need to do is  rebo...
# 5              2  Early in my career, a senior manager told me s...
# 6              3  AD is a collective term for five server roles ...
# 7              2  Not many people are familiar with the term "De...
# 8              3  Scroll animations can make your website feel d...
# 9              1  In the world of enterprise IT, Active Director...
# 10             9  In this technical deep dive, we'll explore how...
# 11             2  liner notes:  Sunday : Did my study sessions o...
# 12             1
# 13             6  Creating a kanaban drag n drop component layou...
# 14             7  In this article, I’ll walk you through setting...
# 15             2  This is a submission for the . As you probably...
# 16             1  After much learning and hard work, I’m excited...
# 17             3  React has always been at the forefront of buil...
# 18             5   Hey there! Today we're going to learn how to ...
# 19             5  I created DOMSculpt for the sole purpose of si...
# 20            13  This tutorial was written by .  The aggregatio...
# 21             1  CSS selectors are more powerful than most deve...
# 22             1  Instructions:After a hard quarter in the offic...
# 23             7  IntroMaterial UI (MUI) is a 2014 JavaScript Li...
# 24             4  Modern cloud applications need scalability, ob...
#
#     word_count sentiment  compound_score
# 0          980  Positive          0.9973
# 1          299  Positive          0.9930
# 2          302  Positive          0.9866
# 3          181   Neutral          0.0000
# 4           28   Neutral          0.0000
# 5          313  Positive          0.5994
# 6          160  Positive          0.9758
# 7          347  Positive          0.9981
# 8          262  Positive          0.9846
# 9           67  Positive          0.6640
# 10         813  Positive          0.9979
# 11         160  Positive          0.9884
# 12           0   Neutral          0.0000
# 13         429  Positive          0.9904
# 14         638  Positive          0.9964
# 15         350  Positive          0.9976
# 16          59  Positive          0.9167
# 17         329  Positive          0.9907
# 18         334  Positive          0.9960
# 19         533  Positive          0.9931
# 20        1607  Positive          0.9994
# 21         115  Positive          0.9830
# 22          81   Neutral          0.0258
# 23         886  Positive          0.9960
# 24         297  Positive          0.9719

# %%
df_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   link             25 non-null     object
#  1   title            25 non-null     object
#  2   time_uploaded    25 non-null     datetime64[ns]
#  3   author           25 non-null     object
#  4   tags             25 non-null     object
#  5   reading_time     25 non-null     int64
#  6   article_content  25 non-null     object
#  7   word_count       25 non-null     int64
#  8   sentiment        25 non-null     object
#  9   compound_score   25 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 2.1+ KB

# %%
#Access the "article_content" column.
#For each value in the column, replace all occurrences of the newline character (\n) with an empty string ("").

#Access the "article_content" column.
df_list["article_content"]= df_list ["article_content"].str.replace('\n','', regex=False)
df_list["article_content"]
# Out:
# 0     Simple, allow yourself to code like a boss! Ho...
# 1     Recently I had a need to clip a compilation vi...
# 2     Lightweight Directory Access Protocol (LDAP) i...
# 3     E para responder essa pergunta, precisamos vol...
# 4     1.The first thing you will need to do is  rebo...
# 5     Early in my career, a senior manager told me s...
# 6     AD is a collective term for five server roles ...
# 7     Not many people are familiar with the term "De...
# 8     Scroll animations can make your website feel d...
# 9     In the world of enterprise IT, Active Director...
# 10    In this technical deep dive, we'll explore how...
# 11    liner notes:  Sunday : Did my study sessions o...
# 12
# 13    Creating a kanaban drag n drop component layou...
# 14    In this article, I’ll walk you through setting...
# 15    This is a submission for the . As you probably...
# 16    After much learning and hard work, I’m excited...
# 17    React has always been at the forefront of buil...
# 18     Hey there! Today we're going to learn how to ...
# 19    I created DOMSculpt for the sole purpose of si...
# 20    This tutorial was written by .  The aggregatio...
# 21    CSS selectors are more powerful than most deve...
# 22    Instructions:After a hard quarter in the offic...
# 23    IntroMaterial UI (MUI) is a 2014 JavaScript Li...
# 24    Modern cloud applications need scalability, ob...
# Name: article_content, dtype: object

# %%
#After the transformations, ensure that each column has the correct data type (e.g., integer, string, date, etc.).
#You might need to use Pandas functions like astype() to enforce these data types.
#Determine the appropriate data types for each column based on the data that it contains.

#convert "Link", "Title", "Author", "Tags","article_content" to string
#df_list["reading_time"] = df_list ["reading_time"].astype(str)

df_list["link"] = df_list["link"].astype(str)
df_list["title"] = df_list ["title"].astype(str)
df_list["author"] = df_list ["author"].astype(str)
df_list["tags"] = df_list ["tags"].astype(str)
df_list["article_content"] = df_list ["article_content"].astype(str)


#convert "reading_time" to integer
df_list["reading_time"] = df_list ["reading_time"].astype(int)

#convert "Compound_Score" to float
df_list["compound_score"] = df_list ["compound_score"].astype(float)

#convert "time_uploaded" to date and time
#["time_uploaded"] = pd.to_datetime(df_list["time_uploaded"]).dt.

df_list["time_uploaded"] = pd.to_datetime(df_list["time_uploaded"])
df_list
#print(df_list.dtypes)
# Out:
#                                                  link  \
# 0   https://dev.to/matthijsschuurman/how-to-code-l...
# 1   https://dev.to/besworks/convert-video-to-anima...
# 2   https://dev.to/timo_reusch/an-introduction-to-...
# 3   https://dev.to/inaciobrwi/terminal-a-famosa-te...
# 4   https://dev.to/victor_kiprotich_9328c6fc/how-t...
# 5   https://dev.to/skilleddevs/programming-doesnt-...
# 6   https://dev.to/timo_reusch/what-exactly-is-act...
# 7   https://dev.to/macmartins/what-is-devrel-and-w...
# 8   https://dev.to/idevgames/how-to-add-scroll-ani...
# 9   https://dev.to/timo_reusch/active-directory-th...
# 10  https://dev.to/ezodude/semantic-caching-for-ll...
# 11    https://dev.to/dwane/day-1122-curtain-call-35pg
# 12  https://dev.to/marlusx/check-out-the-new-stack...
# 13  https://dev.to/leoikeh99/build-a-sleek-sortabl...
# 14  https://dev.to/artur_alekseev/integration-test...
# 15  https://dev.to/pranavjana/kendoreact-component...
# 16  https://dev.to/jondoe-666/cafeto-my-first-plug...
# 17  https://dev.to/aneeqakhan/react-suspense-and-c...
# 18  https://dev.to/mustache/from-json-string-to-ja...
# 19  https://dev.to/js_cipher/meet-domsculpt-a-java...
# 20  https://dev.to/mongodb/better-aggregation-pipe...
# 21  https://dev.to/teki_solves_fb72717580279/maste...
# 22  https://dev.to/maddiepst/transportation-on-vac...
# 23  https://dev.to/peytonstrahan/what-is-material-...
# 24  https://dev.to/sirlawdin/using-iac-terraform-t...
#
#                                                 title time_uploaded  \
# 0                            How to code like a boss?    2025-03-17
# 1   Convert Video to Animated WebP Using FFmpeg Wi...    2025-03-17
# 2                             An introduction to LDAP    2025-03-17
# 3                       Terminal, a famosa tela preta    2025-03-17
# 4   How to change password and username in Kali linux    2025-03-17
# 5   Programming Doesn’t Happen at the Keyboard — B...    2025-03-17
# 6                   What exactly is Active Directory?    2025-03-17
# 7          What is DevRel and why are they important?    2025-03-17
# 8   How to Add Scroll Animations in Webflow, WordP...    2025-03-17
# 9     Active Directory: The Backbone of Enterprise IT    2025-03-17
# 10  Semantic Caching for LLM Execution Plans: How ...    2025-03-17
# 11                            Day 1122 : Curtain Call    2025-03-17
# 12                   Check out the new Stack Builder!    2025-03-17
# 13  Build a Sleek & Sortable Drag-and-Drop Kanban ...    2025-03-17
# 14    Integration Tests Using Cypress Next and Prisma    2025-03-17
# 15                      KendoReact Component Explorer    2025-03-17
# 16                    Cafeto: My First Plugin on PyPI    2025-03-17
# 17  React Suspense and Concurrent Rendering: The F...    2025-03-17
# 18  From JSON String to JavaScript Object: The Ult...    2025-03-17
# 19  Meet DOMSculpt, a JavaScript tool for generati...    2025-03-17
# 20  Better Aggregation Pipeline Support in the Mon...    2025-03-17
# 21  Master Advanced CSS Selectors: Techniques You ...    2025-03-17
# 22                         Transportation on vacation    2025-03-17
# 23            What is Material UI? (React/JavaScript)    2025-03-17
# 24  Using IaC (Terraform) to Deploy a FastAPI Micr...    2025-03-17
#
#                      author                                            tags  \
# 0                  Matthijs                            #kiss#coding#testing
# 1                  Besworks                         #bash#linux#ffmpeg#webp
# 2               Timo Reusch
# 3                 InacioBrw
# 4          Victor Kiprotich                                             #li
# 5              Skilled Devs      #programming#beginners#productivity#career
# 6               Timo Reusch                                      #microsoft
# 7              Obinna Aguwa
# 8                iDev-Games        #webdev#programming#javascript#beginners
# 9               Timo Reusch                                      #microsoft
# 10                Ezo Saleh                       #ai#opensource#go#tooling
# 11          HIPHOP and CODE                 #hiphop#code#coding#lifelongdev
# 12           Marcus Ahlfors                    #webdev#devops#cloud#startup
# 13             Leonard Ikeh            #react#draganddrop#webdev#javascript
# 14         Artur Aliakseyeu               #javascript#cypress#tutorial#node
# 15              Pranav jana  #devchallenge#kendoreactchallenge#react#webdev
# 16         Jonathan Espinal                              #python#api#webdev
# 17              Aneeqa Khan                     #react#ui#webdev#javascript
# 18             Mustache Dev              #webdev#programming#javascript#api
# 19      Temiloluwa Akintade     #webdev#javascript#developertools#beginners
# 20           MongoDB Guests                     #php#mongodb#queries#webdev
# 21              Teki Solves                #webdev#programming#css#frontend
# 22          Madalina Pastiu             #challenge#javascript#codewars#8kyu
# 23           Peyton Strahan
# 24  Salaudeen O. Abdulrasaq                  #devops#aws#datadog#monitoring
#
#     reading_time                                    article_content  \
# 0              9  Simple, allow yourself to code like a boss! Ho...
# 1              3  Recently I had a need to clip a compilation vi...
# 2              2  Lightweight Directory Access Protocol (LDAP) i...
# 3              1  E para responder essa pergunta, precisamos vol...
# 4              1  1.The first thing you will need to do is  rebo...
# 5              2  Early in my career, a senior manager told me s...
# 6              3  AD is a collective term for five server roles ...
# 7              2  Not many people are familiar with the term "De...
# 8              3  Scroll animations can make your website feel d...
# 9              1  In the world of enterprise IT, Active Director...
# 10             9  In this technical deep dive, we'll explore how...
# 11             2  liner notes:  Sunday : Did my study sessions o...
# 12             1
# 13             6  Creating a kanaban drag n drop component layou...
# 14             7  In this article, I’ll walk you through setting...
# 15             2  This is a submission for the . As you probably...
# 16             1  After much learning and hard work, I’m excited...
# 17             3  React has always been at the forefront of buil...
# 18             5   Hey there! Today we're going to learn how to ...
# 19             5  I created DOMSculpt for the sole purpose of si...
# 20            13  This tutorial was written by .  The aggregatio...
# 21             1  CSS selectors are more powerful than most deve...
# 22             1  Instructions:After a hard quarter in the offic...
# 23             7  IntroMaterial UI (MUI) is a 2014 JavaScript Li...
# 24             4  Modern cloud applications need scalability, ob...
#
#     word_count sentiment  compound_score
# 0          980  Positive          0.9973
# 1          299  Positive          0.9930
# 2          302  Positive          0.9866
# 3          181   Neutral          0.0000
# 4           28   Neutral          0.0000
# 5          313  Positive          0.5994
# 6          160  Positive          0.9758
# 7          347  Positive          0.9981
# 8          262  Positive          0.9846
# 9           67  Positive          0.6640
# 10         813  Positive          0.9979
# 11         160  Positive          0.9884
# 12           0   Neutral          0.0000
# 13         429  Positive          0.9904
# 14         638  Positive          0.9964
# 15         350  Positive          0.9976
# 16          59  Positive          0.9167
# 17         329  Positive          0.9907
# 18         334  Positive          0.9960
# 19         533  Positive          0.9931
# 20        1607  Positive          0.9994
# 21         115  Positive          0.9830
# 22          81   Neutral          0.0258
# 23         886  Positive          0.9960
# 24         297  Positive          0.9719

# %%
import pandas as pd
from sqlalchemy import create_engine

# Define your PostgreSQL connection parameters
db_params = {
    'dbname': 'postgres',  # Replace with your database name
    'user': 'testtech',  # Replace with your username
    'password': 'Your_password',  # Replace with your password
    'host': 'testtech.postgres.database.azure.com',  # Replace with your host
    'port': '5432'  # Default PostgreSQL port
}

# Create the connection string using SQLAlchemy's create_engine
engine = create_engine(f'postgresql://{db_params["user"]}:{db_params["password"]}@{db_params["host"]}:{db_params["port"]}/{db_params["dbname"]}')

# Assuming df_list is your DataFrame
# For example, creating a simple DataFrame
# df_list = pd.DataFrame({'column1': [1, 2], 'column2': ['a', 'b']})

# Push data to the PostgreSQL table
df_list.to_sql('hanna', engine, if_exists='replace', index=False)

print("Data has been successfully pushed to the PostgreSQL table.")
# Out:
# Data has been successfully pushed to the PostgreSQL table.
